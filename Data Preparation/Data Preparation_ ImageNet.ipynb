# %% [markdown]
# # ImageNet Downloader
#
# https://towardsdatascience.com/how-to-scrape-the-imagenet-f309e02de1f4
#
# https://github.com/mf1024/ImageNet-Datasets-Downloader
#
# **Purpose:** Download filtered ImageNet dataset

# %%
# Clone
# !git clone https://github.com/mf1024/ImageNet-Datasets-Downloader.git
# %cd ImageNet-Datasets-Downloader
# Out:
# Cloning into 'ImageNet-Datasets-Downloader'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 124 (delta 3), reused 6 (delta 2), pack-reused 113
# Receiving objects: 100% (124/124), 1.57 MiB | 10.82 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/ImageNet-Datasets-Downloader

# %%
# !python ./downloader.py -data_root .. \
                        -use_class_list True \
                        -class_list n02769748 n02992529 n03487533 n04026417 n04548362 \
                        -images_per_class 1000 \
                        -multiprocessing_workers 24
# Out:
# Picked the following clases:
# ['backpack', 'cellular telephone', 'hand luggage', 'purse', 'wallet']
# Scraping images for class "backpack"
# Multiprocessing workers: 24
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 226.0 urls with 144.0 successes
# 63.716814159292035% success rate for is_flickr urls
# 0.02726219925615523 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 226.0 urls with 144.0 successes
# 63.716814159292035% success rate for all urls
# 0.0272631264395184 seconds spent per all succesful image download
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 476.0 urls with 318.0 successes
# 66.80672268907563% success rate for is_flickr urls
# 0.02194391406557095 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 476.0 urls with 318.0 successes
# ...

# %% [markdown]
# # Zip and Download the filtered ImageNet dataset

# %%
# %cd ..
# !zip -r imagenet_images.zip imagenet_images
from google.colab import files
files.download("imagenet_images.zip")
# Out:
# /content
#   adding: imagenet_images/ (stored 0%)
#   adding: imagenet_images/backpack/ (stored 0%)
#   adding: imagenet_images/backpack/860906986_0bb366d6b3.jpg (deflated 1%)
#   adding: imagenet_images/backpack/2214054023_dca2ebbd7f.jpg (deflated 1%)
#   adding: imagenet_images/backpack/2379902866_bdf5ed7814.jpg (deflated 3%)
#   adding: imagenet_images/backpack/1614807387_5f14d05fb6.jpg (deflated 0%)
#   adding: imagenet_images/backpack/2417494242_1f6a4b6ed0.jpg (deflated 5%)
#   adding: imagenet_images/backpack/2630188880_62df5a5c7e.jpg (deflated 0%)
#   adding: imagenet_images/backpack/3054071495_77367d971b.jpg (deflated 1%)
#   adding: imagenet_images/backpack/354965554_64bb605022.jpg (deflated 2%)
#   adding: imagenet_images/backpack/2754194148_13dd7538bc.jpg (deflated 0%)
#   adding: imagenet_images/backpack/2473814903_5f74fe205b.jpg (deflated 1%)
#   adding: imagenet_images/backpack/2572379495_0264aa7656.jpg (deflated 0%)
# ...
